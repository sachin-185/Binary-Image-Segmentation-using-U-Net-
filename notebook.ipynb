# %% [markdown]
# # Training curves and sample inference
# This notebook loads the training history (if available) and shows sample predictions.

# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import numpy as np

# show a sample image and mask
img = cv2.imread('data/images/car_01.jpg')[:,:,::-1]
mask = cv2.imread('data/masks/car_01.png',0)
plt.figure(figsize=(8,4))
plt.subplot(1,2,1); plt.imshow(img); plt.title('Image'); plt.axis('off')
plt.subplot(1,2,2); plt.imshow(mask, cmap='gray'); plt.title('Mask'); plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)
